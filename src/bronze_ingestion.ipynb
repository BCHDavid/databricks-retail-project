# %%
data = [
    (1, "2024-01-01", 100),
    (2, "2024-01-02", 200)
]

df = spark.createDataFrame(data, ["order_id", "date", "amount"])

df.write.format("delta").mode("overwrite").saveAsTable(
    "main.retail.orders_bronze"
)

display(df)
